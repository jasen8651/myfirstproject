# %% [markdown]
# <a href="https://colab.research.google.com/github/jasen8651/python001/blob/master/%EC%B9%B4%EC%B9%B4%EC%98%A4%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%88%98%EC%A7%91.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/python_demo
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/python_demo

# %%
# 이 부분은 처음 한번만 실행하면 됌.
# 코드 수정 - "The reason is that the last Ubuntu update update supports chromium driver just via snap."
# 최근 우분투 업데이트에서 크롬 드라이버 설치를 snap을 이용해서만 하도록 바뀜
# 고로 snap 없이 설치하는 아래 우회 코드로 변경
# 출처 : https://colab.research.google.com/drive/1cbEvuZOhkouYLda3RqiwtbM-o9hxGLyC
# 출처2 : https://stackoverflow.com/questions/75155063/selenium-use-chrome-on-colab-got-unexpectedly-exited

# %%shell
# Ubuntu no longer distributes chromium-browser outside of snap
#
# Proposed solution: https://askubuntu.com/questions/1204571/how-to-install-chromium-without-snap

# Add debian buster
cat > /etc/apt/sources.list.d/debian.list <<'EOF'
deb [arch=amd64 signed-by=/usr/share/keyrings/debian-buster.gpg] http://deb.debian.org/debian buster main
deb [arch=amd64 signed-by=/usr/share/keyrings/debian-buster-updates.gpg] http://deb.debian.org/debian buster-updates main
deb [arch=amd64 signed-by=/usr/share/keyrings/debian-security-buster.gpg] http://deb.debian.org/debian-security buster/updates main
EOF

# Add keys
apt-key adv --keyserver keyserver.ubuntu.com --recv-keys DCC9EFBF77E11517
apt-key adv --keyserver keyserver.ubuntu.com --recv-keys 648ACFD622F3D138
apt-key adv --keyserver keyserver.ubuntu.com --recv-keys 112695A0E562B32A

apt-key export 77E11517 | gpg --dearmour -o /usr/share/keyrings/debian-buster.gpg
apt-key export 22F3D138 | gpg --dearmour -o /usr/share/keyrings/debian-buster-updates.gpg
apt-key export E562B32A | gpg --dearmour -o /usr/share/keyrings/debian-security-buster.gpg

# Prefer debian repo for chromium* packages only
# Note the double-blank lines between entries
cat > /etc/apt/preferences.d/chromium.pref << 'EOF'
Package: *
Pin: release a=eoan
Pin-Priority: 500


Package: *
Pin: origin "deb.debian.org"
Pin-Priority: 300


Package: chromium*
Pin: origin "deb.debian.org"
Pin-Priority: 700
EOF

# Install chromium and chromium-driver
apt-get update
apt-get install chromium chromium-driver

# Install selenium
pip install selenium
# Out:
# Executing: /tmp/apt-key-gpghome.nodMdoYf76/gpg.1.sh --keyserver keyserver.ubuntu.com --recv-keys DCC9EFBF77E11517
# gpg: key DCC9EFBF77E11517: public key "Debian Stable Release Key (10/buster) <debian-release@lists.debian.org>" imported
# gpg: Total number processed: 1
# gpg:               imported: 1
# Executing: /tmp/apt-key-gpghome.qW76250YIk/gpg.1.sh --keyserver keyserver.ubuntu.com --recv-keys 648ACFD622F3D138
# gpg: key DC30D7C23CBBABEE: public key "Debian Archive Automatic Signing Key (10/buster) <ftpmaster@debian.org>" imported
# gpg: Total number processed: 1
# gpg:               imported: 1
# Executing: /tmp/apt-key-gpghome.x4sFA4G2RY/gpg.1.sh --keyserver keyserver.ubuntu.com --recv-keys 112695A0E562B32A
# gpg: key 4DFAB270CAA96DFA: public key "Debian Security Archive Automatic Signing Key (10/buster) <ftpmaster@debian.org>" imported
# gpg: Total number processed: 1
# gpg:               imported: 1
# Warning: apt-key output should not be parsed (stdout is not a terminal)
# Warning: apt-key output should not be parsed (stdout is not a terminal)
# Warning: apt-key output should not be parsed (stdout is not a terminal)
# Get:1 http://deb.debian.org/debian buster InRelease [122 kB]
# Get:2 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal InRelease [18.1 kB]
# Get:3 http://deb.debian.org/debian buster-updates InRelease [56.6 kB]
# Get:4 http://deb.debian.org/debian-security buster/updates InRelease [34.8 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu focal InRelease
# Get:6 http://archive.ubuntu.com/ubuntu focal-updates InRelease [114 kB]
# Get:7 https://cloud.r-project.org/bin/linux/ubuntu focal-cran40/ InRelease [3,622 B]
# Hit:8 http://ppa.launchpad.net/cran/libgit2/ubuntu focal InRelease
# Get:9 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu focal InRelease [18.1 kB]
# Get:10 http://archive.ubuntu.com/ubuntu focal-backports InRelease [108 kB]
# Hit:11 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu focal InRelease
# Get:12 http://deb.debian.org/debian buster/main amd64 Packages [10.7 MB]
# Get:13 http://security.ubuntu.com/ubuntu focal-security InRelease [114 kB]
# Get:14 http://deb.debian.org/debian buster-updates/main amd64 Packages [9,745 B]
# Get:15 http://deb.debian.org/debian-security buster/updates/main amd64 Packages [550 kB]
# Ign:16 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu2004/x86_64  InRelease
# Hit:17 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease
# Hit:18 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu2004/x86_64  Release
# Get:19 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal/main Sources [2,385 kB]
# Get:20 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal/main amd64 Packages [1,130 kB]
# Get:21 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 Packages [2,952 kB]
# Get:22 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 Packages [1,295 kB]
# Get:23 http://archive.ubuntu.com/ubuntu focal-updates/restricted amd64 Packages [2,050 kB]
# Get:24 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu focal/main amd64 Packages [29.5 kB]
# Get:26 http://security.ubuntu.com/ubuntu focal-security/main amd64 Packages [2,479 kB]
# Fetched 24.2 MB in 3s (8,503 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-510
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   chromium-common chromium-sandbox libevent-2.1-6 libicu63 libimobiledevice6
#   libjpeg62-turbo libplist3 libre2-5 libu2f-udev libusbmuxd6 libvpx5
#   libxxf86dga1 upower usbmuxd x11-utils
# Suggested packages:
#   chromium-l10n chromium-shell libusbmuxd-tools mesa-utils
# The following NEW packages will be installed:
#   chromium chromium-common chromium-driver chromium-sandbox libevent-2.1-6
#   libicu63 libimobiledevice6 libjpeg62-turbo libplist3 libre2-5 libu2f-udev
#   libusbmuxd6 libvpx5 libxxf86dga1 upower usbmuxd x11-utils
# 0 upgraded, 17 newly installed, 0 to remove and 23 not upgraded.
# Need to get 74.6 MB of archives.
# After this operation, 256 MB of additional disk space will be used.
# Get:1 http://deb.debian.org/debian buster/main amd64 libevent-2.1-6 amd64 2.1.8-stable-4 [177 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/main amd64 libre2-5 amd64 20200101+dfsg-1build1 [162 kB]
# Get:3 http://deb.debian.org/debian buster/main amd64 libicu63 amd64 63.1-6+deb10u3 [8,293 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal/main amd64 libxxf86dga1 amd64 2:1.1.5-0ubuntu1 [12.0 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal/main amd64 x11-utils amd64 7.7+5 [199 kB]
# Get:6 http://archive.ubuntu.com/ubuntu focal/main amd64 libplist3 amd64 2.1.0-4build2 [31.6 kB]
# Get:7 http://archive.ubuntu.com/ubuntu focal/main amd64 libusbmuxd6 amd64 2.0.1-2 [19.1 kB]
# Get:8 http://archive.ubuntu.com/ubuntu focal/main amd64 libimobiledevice6 amd64 1.2.1~git20191129.9f79242-1build1 [65.2 kB]
# Get:9 http://archive.ubuntu.com/ubuntu focal/main amd64 libu2f-udev all 1.1.10-1 [6,108 B]
# Get:10 http://archive.ubuntu.com/ubuntu focal/main amd64 upower amd64 0.99.11-1build2 [104 kB]
# Get:11 http://archive.ubuntu.com/ubuntu focal/main amd64 usbmuxd amd64 1.1.1~git20191130.9af2b12-1 [38.4 kB]
# Get:12 http://deb.debian.org/debian buster/main amd64 libjpeg62-turbo amd64 1:1.5.2-2+deb10u1 [133 kB]
# Get:13 http://deb.debian.org/debian buster/main amd64 libvpx5 amd64 1.7.0-3+deb10u1 [800 kB]
# Get:14 http://deb.debian.org/debian buster/main amd64 chromium-common amd64 90.0.4430.212-1~deb10u1 [1,423 kB]
# Get:15 http://deb.debian.org/debian buster/main amd64 chromium amd64 90.0.4430.212-1~deb10u1 [58.3 MB]
# Get:16 http://deb.debian.org/debian buster/main amd64 chromium-driver amd64 90.0.4430.212-1~deb10u1 [4,703 kB]
# Get:17 http://deb.debian.org/debian buster/main amd64 chromium-sandbox amd64 90.0.4430.212-1~deb10u1 [146 kB]
# Fetched 74.6 MB in 1s (108 MB/s)
# Selecting previously unselected package libevent-2.1-6:amd64.
# (Reading database ... 128048 files and directories currently installed.)
# Preparing to unpack .../00-libevent-2.1-6_2.1.8-stable-4_amd64.deb ...
# Unpacking libevent-2.1-6:amd64 (2.1.8-stable-4) ...
# Selecting previously unselected package libicu63:amd64.
# Preparing to unpack .../01-libicu63_63.1-6+deb10u3_amd64.deb ...
# Unpacking libicu63:amd64 (63.1-6+deb10u3) ...
# Selecting previously unselected package libjpeg62-turbo:amd64.
# Preparing to unpack .../02-libjpeg62-turbo_1%3a1.5.2-2+deb10u1_amd64.deb ...
# Unpacking libjpeg62-turbo:amd64 (1:1.5.2-2+deb10u1) ...
# Selecting previously unselected package libre2-5:amd64.
# Preparing to unpack .../03-libre2-5_20200101+dfsg-1build1_amd64.deb ...
# Unpacking libre2-5:amd64 (20200101+dfsg-1build1) ...
# Selecting previously unselected package libvpx5:amd64.
# Preparing to unpack .../04-libvpx5_1.7.0-3+deb10u1_amd64.deb ...
# Unpacking libvpx5:amd64 (1.7.0-3+deb10u1) ...
# Selecting previously unselected package libxxf86dga1:amd64.
# Preparing to unpack .../05-libxxf86dga1_2%3a1.1.5-0ubuntu1_amd64.deb ...
# Unpacking libxxf86dga1:amd64 (2:1.1.5-0ubuntu1) ...
# Selecting previously unselected package x11-utils.
# Preparing to unpack .../06-x11-utils_7.7+5_amd64.deb ...
# Unpacking x11-utils (7.7+5) ...
# Selecting previously unselected package chromium-common.
# Preparing to unpack .../07-chromium-common_90.0.4430.212-1~deb10u1_amd64.deb ...
# Unpacking chromium-common (90.0.4430.212-1~deb10u1) ...
# Selecting previously unselected package chromium.
# Preparing to unpack .../08-chromium_90.0.4430.212-1~deb10u1_amd64.deb ...
# Unpacking chromium (90.0.4430.212-1~deb10u1) ...
# Selecting previously unselected package chromium-driver.
# Preparing to unpack .../09-chromium-driver_90.0.4430.212-1~deb10u1_amd64.deb ...
# Unpacking chromium-driver (90.0.4430.212-1~deb10u1) ...
# Selecting previously unselected package chromium-sandbox.
# Preparing to unpack .../10-chromium-sandbox_90.0.4430.212-1~deb10u1_amd64.deb ...
# Unpacking chromium-sandbox (90.0.4430.212-1~deb10u1) ...
# Selecting previously unselected package libplist3:amd64.
# Preparing to unpack .../11-libplist3_2.1.0-4build2_amd64.deb ...
# Unpacking libplist3:amd64 (2.1.0-4build2) ...
# Selecting previously unselected package libusbmuxd6:amd64.
# Preparing to unpack .../12-libusbmuxd6_2.0.1-2_amd64.deb ...
# Unpacking libusbmuxd6:amd64 (2.0.1-2) ...
# Selecting previously unselected package libimobiledevice6:amd64.
# Preparing to unpack .../13-libimobiledevice6_1.2.1~git20191129.9f79242-1build1_amd64.deb ...
# Unpacking libimobiledevice6:amd64 (1.2.1~git20191129.9f79242-1build1) ...
# Selecting previously unselected package libu2f-udev.
# Preparing to unpack .../14-libu2f-udev_1.1.10-1_all.deb ...
# Unpacking libu2f-udev (1.1.10-1) ...
# Selecting previously unselected package upower.
# Preparing to unpack .../15-upower_0.99.11-1build2_amd64.deb ...
# Unpacking upower (0.99.11-1build2) ...
# Selecting previously unselected package usbmuxd.
# Preparing to unpack .../16-usbmuxd_1.1.1~git20191130.9af2b12-1_amd64.deb ...
# Unpacking usbmuxd (1.1.1~git20191130.9af2b12-1) ...
# Setting up libplist3:amd64 (2.1.0-4build2) ...
# Setting up libu2f-udev (1.1.10-1) ...
# Failed to send reload request: No such file or directory
# Setting up libxxf86dga1:amd64 (2:1.1.5-0ubuntu1) ...
# Setting up chromium-sandbox (90.0.4430.212-1~deb10u1) ...
# Setting up libicu63:amd64 (63.1-6+deb10u3) ...
# Setting up libjpeg62-turbo:amd64 (1:1.5.2-2+deb10u1) ...
# Setting up libevent-2.1-6:amd64 (2.1.8-stable-4) ...
# Setting up libusbmuxd6:amd64 (2.0.1-2) ...
# Setting up x11-utils (7.7+5) ...
# Setting up libre2-5:amd64 (20200101+dfsg-1build1) ...
# Setting up chromium-common (90.0.4430.212-1~deb10u1) ...
# Setting up libimobiledevice6:amd64 (1.2.1~git20191129.9f79242-1build1) ...
# Setting up libvpx5:amd64 (1.7.0-3+deb10u1) ...
# Setting up upower (0.99.11-1build2) ...
# Setting up usbmuxd (1.1.1~git20191130.9af2b12-1) ...
# Warning: The home dir /var/lib/usbmux you specified can't be accessed: No such file or directory
# Adding system user `usbmux' (UID 107) ...
# Adding new user `usbmux' (UID 107) with group `plugdev' ...
# Not creating home directory `/var/lib/usbmux'.
# Setting up chromium (90.0.4430.212-1~deb10u1) ...
# update-alternatives: using /usr/bin/chromium to provide /usr/bin/x-www-browser (x-www-browser) in auto mode
# update-alternatives: using /usr/bin/chromium to provide /usr/bin/gnome-www-browser (gnome-www-browser) in auto mode
# Setting up chromium-driver (90.0.4430.212-1~deb10u1) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for dbus (1.12.16-2ubuntu2.3) ...
# Processing triggers for mime-support (3.64ubuntu1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting selenium
#   Downloading selenium-4.8.0-py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 73.0 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.8/dist-packages (from selenium) (2022.12.7)
# Collecting trio~=0.17
#   Downloading trio-0.22.0-py3-none-any.whl (384 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 384.9/384.9 KB 31.1 MB/s eta 0:00:00
# Collecting urllib3[socks]~=1.26
#   Downloading urllib3-1.26.14-py2.py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 KB 16.3 MB/s eta 0:00:00
# Collecting trio-websocket~=0.9
#   Downloading trio_websocket-0.9.2-py3-none-any.whl (16 kB)
# Collecting async-generator>=1.9
#   Downloading async_generator-1.10-py3-none-any.whl (18 kB)
# Collecting sniffio
#   Downloading sniffio-1.3.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: idna in /usr/local/lib/python3.8/dist-packages (from trio~=0.17->selenium) (2.10)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.8/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Collecting exceptiongroup>=1.0.0rc9
#   Downloading exceptiongroup-1.1.0-py3-none-any.whl (14 kB)
# Collecting outcome
#   Downloading outcome-1.2.0-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.8/dist-packages (from trio~=0.17->selenium) (22.2.0)
# Collecting wsproto>=0.14
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.8/dist-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Collecting h11<1,>=0.9.0
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 KB 6.9 MB/s eta 0:00:00
# Installing collected packages: urllib3, sniffio, outcome, h11, exceptiongroup, async-generator, wsproto, trio, trio-websocket, selenium
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# Successfully installed async-generator-1.10 exceptiongroup-1.1.0 h11-0.14.0 outcome-1.2.0 selenium-4.8.0 sniffio-1.3.0 trio-0.22.0 trio-websocket-0.9.2 urllib3-1.26.14 wsproto-1.2.0

# %%
# !pip install selenium
# !pip install -U  urllib3 requests


#구글코랩 selenium4
# !apt-get update
# !apt install chromium-chromedriver

# !cp /usr/lib/chromium-browser/chromedriver /usr/bin
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: selenium in /usr/local/lib/python3.8/dist-packages (4.8.0)
# Requirement already satisfied: trio-websocket~=0.9 in /usr/local/lib/python3.8/dist-packages (from selenium) (0.9.2)
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.8/dist-packages (from selenium) (2022.12.7)
# Requirement already satisfied: urllib3[socks]~=1.26 in /usr/local/lib/python3.8/dist-packages (from selenium) (1.26.14)
# Requirement already satisfied: trio~=0.17 in /usr/local/lib/python3.8/dist-packages (from selenium) (0.22.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.8/dist-packages (from trio~=0.17->selenium) (2.10)
# Requirement already satisfied: async-generator>=1.9 in /usr/local/lib/python3.8/dist-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: outcome in /usr/local/lib/python3.8/dist-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.8/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.8/dist-packages (from trio~=0.17->selenium) (22.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in /usr/local/lib/python3.8/dist-packages (from trio~=0.17->selenium) (1.1.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.8/dist-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: wsproto>=0.14 in /usr/local/lib/python3.8/dist-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.8/dist-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.8/dist-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.8/dist-packages (1.26.14)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (2.25.1)
# Collecting requests
#   Downloading requests-2.28.2-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 KB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests) (2.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.8/dist-packages (from requests) (2.1.1)
# Installing collected packages: requests
#   Attempting uninstall: requests
#     Found existing installation: requests 2.25.1
#     Uninstalling requests-2.25.1:
#       Successfully uninstalled requests-2.25.1
# Successfully installed requests-2.28.2
# Hit:1 http://deb.debian.org/debian buster InRelease
# Hit:2 http://security.ubuntu.com/ubuntu focal-security InRelease
# Hit:3 http://deb.debian.org/debian buster-updates InRelease
# Hit:4 http://deb.debian.org/debian-security buster/updates InRelease
# Hit:5 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal InRelease
# Hit:6 https://cloud.r-project.org/bin/linux/ubuntu focal-cran40/ InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu focal InRelease
# Hit:8 http://ppa.launchpad.net/cran/libgit2/ubuntu focal InRelease
# Hit:9 http://archive.ubuntu.com/ubuntu focal-updates InRelease
# Hit:10 http://archive.ubuntu.com/ubuntu focal-backports InRelease
# Hit:11 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu focal InRelease
# Hit:12 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu focal InRelease
# Ign:13 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu2004/x86_64  InRelease
# Hit:14 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease
# Hit:15 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu2004/x86_64  Release
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-510
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   apparmor chromium-browser liblzo2-2 snapd squashfs-tools
# Suggested packages:
#   apparmor-profiles-extra apparmor-utils
# The following NEW packages will be installed:
#   apparmor chromium-browser chromium-chromedriver liblzo2-2 snapd
#   squashfs-tools
# 0 upgraded, 6 newly installed, 0 to remove and 23 not upgraded.
# Need to get 38.6 MB of archives.
# After this operation, 174 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 apparmor amd64 2.13.3-7ubuntu5.1 [494 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/main amd64 liblzo2-2 amd64 2.10-2 [50.8 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 squashfs-tools amd64 1:4.4-1ubuntu0.3 [117 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 snapd amd64 2.58+20.04 [37.9 MB]
# Get:5 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 chromium-browser amd64 1:85.0.4183.83-0ubuntu0.20.04.2 [48.3 kB]
# Get:6 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 chromium-chromedriver amd64 1:85.0.4183.83-0ubuntu0.20.04.2 [2,496 B]
# Fetched 38.6 MB in 1s (75.1 MB/s)
# Preconfiguring packages ...
# Selecting previously unselected package apparmor.
# (Reading database ... 128262 files and directories currently installed.)
# Preparing to unpack .../apparmor_2.13.3-7ubuntu5.1_amd64.deb ...
# Unpacking apparmor (2.13.3-7ubuntu5.1) ...
# Selecting previously unselected package liblzo2-2:amd64.
# Preparing to unpack .../liblzo2-2_2.10-2_amd64.deb ...
# Unpacking liblzo2-2:amd64 (2.10-2) ...
# Selecting previously unselected package squashfs-tools.
# Preparing to unpack .../squashfs-tools_1%3a4.4-1ubuntu0.3_amd64.deb ...
# Unpacking squashfs-tools (1:4.4-1ubuntu0.3) ...
# Selecting previously unselected package snapd.
# Preparing to unpack .../snapd_2.58+20.04_amd64.deb ...
# Unpacking snapd (2.58+20.04) ...
# Setting up apparmor (2.13.3-7ubuntu5.1) ...
# Created symlink /etc/systemd/system/sysinit.target.wants/apparmor.service → /lib/systemd/system/apparmor.service.
# Setting up liblzo2-2:amd64 (2.10-2) ...
# Setting up squashfs-tools (1:4.4-1ubuntu0.3) ...
# Setting up snapd (2.58+20.04) ...
# Created symlink /etc/systemd/system/multi-user.target.wants/snapd.aa-prompt-listener.service → /lib/systemd/system/snapd.aa-prompt-listener.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/snapd.apparmor.service → /lib/systemd/system/snapd.apparmor.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/snapd.autoimport.service → /lib/systemd/system/snapd.autoimport.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/snapd.core-fixup.service → /lib/systemd/system/snapd.core-fixup.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/snapd.recovery-chooser-trigger.service → /lib/systemd/system/snapd.recovery-chooser-trigger.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/snapd.seeded.service → /lib/systemd/system/snapd.seeded.service.
# Created symlink /etc/systemd/system/cloud-final.service.wants/snapd.seeded.service → /lib/systemd/system/snapd.seeded.service.
# Created symlink /etc/systemd/system/multi-user.target.wants/snapd.service → /lib/systemd/system/snapd.service.
# Created symlink /etc/systemd/system/timers.target.wants/snapd.snap-repair.timer → /lib/systemd/system/snapd.snap-repair.timer.
# Created symlink /etc/systemd/system/sockets.target.wants/snapd.socket → /lib/systemd/system/snapd.socket.
# Created symlink /etc/systemd/system/final.target.wants/snapd.system-shutdown.service → /lib/systemd/system/snapd.system-shutdown.service.
# Selecting previously unselected package chromium-browser.
# (Reading database ... 128555 files and directories currently installed.)
# Preparing to unpack .../chromium-browser_1%3a85.0.4183.83-0ubuntu0.20.04.2_amd64.deb ...
# => Installing the chromium snap
# ==> Checking connectivity with the snap store
# ===> System doesn't have a working snapd, skipping
# Unpacking chromium-browser (1:85.0.4183.83-0ubuntu0.20.04.2) ...
# Selecting previously unselected package chromium-chromedriver.
# Preparing to unpack .../chromium-chromedriver_1%3a85.0.4183.83-0ubuntu0.20.04.2_amd64.deb ...
# Unpacking chromium-chromedriver (1:85.0.4183.83-0ubuntu0.20.04.2) ...
# dpkg: error processing archive /var/cache/apt/archives/chromium-chromedriver_1%3a85.0.4183.83-0ubuntu0.20.04.2_amd64.deb (--unpack):
#  trying to overwrite '/usr/bin/chromedriver', which is also in package chromium-driver 90.0.4430.212-1~deb10u1
# Errors were encountered while processing:
#  /var/cache/apt/archives/chromium-chromedriver_1%3a85.0.4183.83-0ubuntu0.20.04.2_amd64.deb
# E: Sub-process /usr/bin/dpkg returned an error code (1)
# cp: cannot stat '/usr/lib/chromium-browser/chromedriver': No such file or directory

# %%
# !apt-get update
# !apt install chromium-chromedriver
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin
# Out:
# Hit:1 http://deb.debian.org/debian buster InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu focal InRelease
# Hit:3 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal InRelease
# Hit:4 http://deb.debian.org/debian buster-updates InRelease
# Hit:5 http://deb.debian.org/debian-security buster/updates InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu focal-updates InRelease
# Hit:7 http://ppa.launchpad.net/cran/libgit2/ubuntu focal InRelease
# Hit:8 https://cloud.r-project.org/bin/linux/ubuntu focal-cran40/ InRelease
# Hit:9 http://archive.ubuntu.com/ubuntu focal-backports InRelease
# Hit:10 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu focal InRelease
# Hit:11 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu focal InRelease
# Hit:12 http://security.ubuntu.com/ubuntu focal-security InRelease
# Ign:13 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu2004/x86_64  InRelease
# Hit:14 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease
# Hit:15 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu2004/x86_64  Release
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-510
# Use 'apt autoremove' to remove it.
# The following NEW packages will be installed:
#   chromium-chromedriver
# 0 upgraded, 1 newly installed, 0 to remove and 23 not upgraded.
# 1 not fully installed or removed.
# Need to get 2,496 B of archives.
# After this operation, 77.8 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 chromium-chromedriver amd64 1:85.0.4183.83-0ubuntu0.20.04.2 [2,496 B]
# Fetched 2,496 B in 0s (74.6 kB/s)
# (Reading database ... 128569 files and directories currently installed.)
# Preparing to unpack .../chromium-chromedriver_1%3a85.0.4183.83-0ubuntu0.20.04.2_amd64.deb ...
# Unpacking chromium-chromedriver (1:85.0.4183.83-0ubuntu0.20.04.2) ...
# dpkg: error processing archive /var/cache/apt/archives/chromium-chromedriver_1%3a85.0.4183.83-0ubuntu0.20.04.2_amd64.deb (--unpack):
#  trying to overwrite '/usr/bin/chromedriver', which is also in package chromium-driver 90.0.4430.212-1~deb10u1
# Errors were encountered while processing:
#  /var/cache/apt/archives/chromium-chromedriver_1%3a85.0.4183.83-0ubuntu0.20.04.2_amd64.deb
# E: Sub-process /usr/bin/dpkg returned an error code (1)
# cp: cannot stat '/usr/lib/chromium-browser/chromedriver': No such file or directory

# %%
# -*- coding: UTF-8 -*-
import time
from selenium import webdriver
from selenium.webdriver.common.by import By

# %%
gu_list = ['남원읍']

# %%
# 25개구 for문으로 돌려서 카페 정보 크롤링하기

import os
from time import sleep
import time
import re
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.common.exceptions import ElementNotInteractableException
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

##########################################################################
##################### variable related selenium ##########################
##########################################################################
# 서울 특별시 구 리스트
gu_list = ['남원읍']


# csv 파일에 헤더 만들어 주기

for index, gu_name in enumerate(gu_list):
    k=0
    fileName = '남원읍숙박.csv' # index.__str__() + '_' + gu_name + '.'+'csv'
    file = open(fileName, 'w', encoding='utf-8-sig')
    file.write("url" + "|" +"구" + "|" + "ID" + "|" +"숙박명" + "|" + "타입" +"|" + "주소" + "|" + "영업시간" + "|" + "전화번호" + "|" + "대표사진주소" + "|" + "평점" +"\n")
    file.close()                                    # 처음에 csv파일에 칼럼명 만들어주기
    
    options = webdriver.ChromeOptions()
    options.add_argument('--headless')        # Head-less 설정
    options.add_argument('--no-sandbox')
    options.add_argument('--disable-dev-shm-usage')
    driver = webdriver.Chrome('chromedriver', options=options)
    # options.add_argument('headless')
    options.add_argument("Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.198 Safari/537.36   ")
    options.add_argument('lang=ko_KR')
    chromedriver_path = "D:/lsy/chromedriver.exe"
    #driver = webdriver.Chrome(os.path.join(os.getcwd(), chromedriver_path), options=options)  # chromedriver 열기
    driver.get('https://map.kakao.com/')  # 주소 가져오기
     #1.search텍스트창 가져오기
    search_area = driver.find_element(By.XPATH,'//*[@id="search.keyword.query"]') # 검색 창
    search_area.send_keys(gu_name + ' 숙박')  # 검색어 입력
    #2.검색누르기
    driver.find_element(By.XPATH,'//*[@id="search.keyword.submit"]').send_keys(Keys.ENTER)  # Enter로 검색
    driver.implicitly_wait(3) # 기다려 주자
    #3.더보기란 클릭하기
    more_page = driver.find_element(By.ID,"info.search.place.more")
    # more_page.click()
    #more_page.send_keys(Keys.ENTER) # 더보기 누르고
    driver.execute_script("arguments[0].click();",more_page)
    # print(more_page)
    # 첫 번째 검색 페이지 끝
    # driver.implicitly_wait(5) # 기다려 주자
    time.sleep(1)

    next_btn = driver.find_element(By.ID,"info.search.page.next")
    has_next = "disabled" not in next_btn.get_attribute("class").split(" ")
    Page = 1
    while has_next: # 다음 페이지가 있으면 loop
      
    # for i in range(2, 6): # 2, 3, 4, 5
        file = open(fileName, 'a', encoding='utf-8')
        time.sleep(1)

        #info\.search\.page\.no1 ~ .no5
        page_links = driver.find_elements(By.CSS_SELECTOR,"#info\.search\.page a")
        pages = [link for link in page_links if "HIDDEN" not in link.get_attribute("class").split(" ")]
        # print(len(pages), "개의 페이지 있음")
        # pages를 하나씩 클릭하면서
        for i in range(1, 6):
            xPath = '//*[@id="info.search.page.no' + str(i) + '"]'
            try:
                page = driver.find_element(By.XPATH,xPath)
                page.send_keys(Keys.ENTER)
            except ElementNotInteractableException:
                print('End of Page')
                break;
            sleep(1)
            place_lists = driver.find_elements(By.CSS_SELECTOR,'#info\.search\.place\.list > li')
            for p in place_lists: 
                store_html = p.get_attribute('innerHTML')
                store_info = BeautifulSoup(store_html, "html.parser")
                # BS -> 분석
                #
                place_name = store_info.select('.head_item > .tit_name > .link_name')
                # print(place_name)

                if len(place_name) == 0:
                    continue # 광고
                place_name = store_info.select('.head_item > .tit_name > .link_name')[0].text
                place_type = store_info.select('.head_item > .subcategory')[0].text
                place_address = store_info.select('.info_item > .addr > p')[0].text
                place_address2 = place_address.replace(',', '')
                place_hour = store_info.select('.info_item > .openhour > p > a')[0].text
                place_hour2 = place_hour.replace(',', '')
                place_tel = store_info.select('.info_item > .contact > span')[0].text
                place_star = store_info.select('div.rating.clickArea > span.score > em')[0].text
                url = store_info.select("div.info_item > div.contact.clickArea > a.moreview")
                for j in url:
                  link = j["href"]
                  print(link)
                  file.write(link+"|")
                
  
                # 사진url 수집
                detail = p.find_element(By.CSS_SELECTOR,'div.info_item > div.contact.clickArea > a.moreview')
                
                detail.send_keys(Keys.ENTER)

                #상세탭으로 전환
                driver.switch_to.window(driver.window_handles[-1])
                time.sleep(1)
                place_photo = ""
                try:
                    photo = driver.find_element(By.CSS_SELECTOR,'span.bg_present')
                    photo_url = photo.get_attribute('style')
                    m = re.search('"(.+?)"', photo_url)
                    if m:
                        place_photo = m.group(1)
                    else:
                        place_photo = ""
                except:
                    place_photo = ""

                driver.close()
                driver.switch_to.window(driver.window_handles[0])
                time.sleep(1)
                print(place_name, place_photo,place_star)
                k+=1
                file.write("MA"+ "|"+str(k)+"|"+place_name + "|" + place_type +"|" + place_address2 + "|" + place_hour2 + "|" + place_tel + "|" + place_photo + "|"+ place_star +"\n")
            print(i, ' of', ' [ ' , Page, ' ] ')
        next_btn = driver.find_element(By.ID,"info.search.page.next")
        has_next = "disabled" not in next_btn.get_attribute("class").split(" ")
        if not has_next:
            print('Arrow is Disabled')
            driver.close()
            file.close()
            break # 다음 페이지 없으니까 종료
        else: # 다음 페이지 있으면
            Page += 1
            driver.execute_script("arguments[0].click();",next_btn)
    print("End of Crawl")
# Out:
# https://place.map.kakao.com/16434989
# 금호제주리조트 //t1.kakaocdn.net/thumb/T800x0.q80/?fname=http%3A%2F%2Ft1.daumcdn.net%2Fplace%2F73CB9E6EEF364E98BEF5130389570E75 3.2
# https://place.map.kakao.com/27470228
# 코업시티호텔 하버뷰 //t1.kakaocdn.net/thumb/T800x0.q80/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flocalfiy%2Fsearchregister_470774142 3.9
# https://place.map.kakao.com/27386975
# 기린빌라리조트 //t1.kakaocdn.net/thumb/T800x0.q80/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flocalfiy%2F79A4220B767545D1A47C0FCB1DCCB5E2 3.3
# https://place.map.kakao.com/14558919
# 부영CC관광호텔 //t1.kakaocdn.net/thumb/T800x0.q80/?fname=http%3A%2F%2Ft1.daumcdn.net%2Fcfile%2F156302344F025AC216 2.6
# https://place.map.kakao.com/1989329951
# 은빌레펜션 //t1.kakaocdn.net/thumb/T800x0.q80/?fname=http%3A%2F%2Ft1.kakaocdn.net%2Ffiy_reboot%2Fplace%2F89C31C9E860643D4B1F3B06C3C663508 4.5
# https://place.map.kakao.com/10634311
# 예이츠산장 //t1.kakaocdn.net/thumb/T800x0.q80/?fname=http%3A%2F%2Ft1.daumcdn.net%2Fcfile%2F1243EE4B4FD1825839 2.5
# https://place.map.kakao.com/27072789
# 바다랑파도랑펜션  5.0
# https://place.map.kakao.com/20373867
# 큰엉해올레펜션 //t1.kakaocdn.net/thumb/T800x0.q80/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flocalfiy%2FAC32506F0272415B9556B96CBA6235FA 4.6
# https://place.map.kakao.com/18268425
# 노인과바다펜션 //t1.kakaocdn.net/thumb/T800x0.q80/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flocalfiy%2FBFB44718CDB84A0EB86370535717A5EF 5.0
# https://place.map.kakao.com/821311400
# 하르방고을펜션 //t1.kakaocdn.net/thumb/T800x0.q80/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flocalfiy%2F8F832DE1B4EE408CB7683C07881240A3 0.0
# https://place.map.kakao.com/1212103874
# 제주게토게스트하우스파티 //t1.kakaocdn.net/thumb/T800x0.q80/?fname=http%3A%2F%2Ft1.kakaocdn.net%2Fmystore%2F6DE798AF3AE140CF804FFA959D439B0E 4.5
# https://place.map.kakao.com/582626886
# 두리안펜션 //t1.kakaocdn.net/thumb/T800x0.q80/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flocalfiy%2
# https://place.map.kakao.com/25702163
# 렌트하우스맑음  0.0
# https://place.map.kakao.com/1050820836
# 스테이이공  0.0
# https://place.map.kakao.com/1283264741
# 아빈스  5.0
# https://place.map.kakao.com/1673239417
# 라이트하우스  0.0
# https://place.map.kakao.com/1691313460
# 스테이르브아펜션  0.0
# https://place.map.kakao.com/634295265
# 동백바다게스트하우스  0.0
# https://place.map.kakao.com/26942568
# 설코지민박  5.0
# https://place.map.kakao.com/1379957979
# 미깡밭스테이 삼삼은구  0.0
# https://place.map.kakao.com/25459120
# 제주명팬션 //t1.kakaocdn.net/thumb/T800x0.q80/?fname=http%3A%2F%2Ft1.kakaocdn.net%2Ffiy_reboot%2Fplace%2FF4E398D596CE40649E889255718937CE 0.0
# https://place.map.kakao.com/1722028357
# 걸어보지 못한 길 펜션 //t1.kakaocdn.net/thumb/T800x0.q80/?fname=http%3A%2F%2Ft1.daumcdn.net%2Fcfile%2F247FDB4957B3BBB706 0.0
# https://place.map.kakao.com/2036510026
# 소담JJ펜션  0.0
# https://place.map.kakao.com/1945558806
# 제주하루펜션  5.0
# https://place.map.kakao.com/955134694
# 귤낭귤낭  0.0
# 4  of  [  3  ]
# https://place.map.kakao.com/27335436
# 독채펜션현  5.0
# https://place.map.kakao.com/1855024334
# 위앤미  0.0
# https://place.map.kakao.com/23972659
# 양지통나무펜션  1.0
# https://place.map.kakao.com/1541776330
# 맑은숨펜션  0.0
# https://place.map.kakao.com/1720699167
# 녹음실제주  0.0
# https://place.map.kakao.com/2051365556
# 멜리아모텔  0.0
# https://place.map.kakao.com/1187676593
# 미니 쇠소깍펜션  0.0
# https://place.map.kakao.com/1730380345
# 제주클래식위미 //t1.kakaocdn.net/thumb/T800x0.q80/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flocalfiy%2F36F5AC6626A040959880DE2F305F794A 0.0
# https://place.map.kakao.com/27456080
# 위미캠프하우스  5.0
# https://place.map.kakao.com/20327777
# 산타개리 게스트하우스  0.0
# https://place.map.kakao.com/518083348
# 귤림추색 //t1.kakaocdn.net/thumb/T800x0.q80/?fname=http%3A%2F%2Ft1.kakaocdn.net%2Ffiy_reboot%2Fplace%2F8F1DB77C1F3546A18CC4BB423239A0CA 5.0
# https://place.map.kakao.com/1570881241
# 제주삼춘네민박 //t1.kakaocdn.net/thumb/T800x0.q80/?fname=http%3A%2F%2Ft1.kakaocdn.net%2Ffiy_reboot%2Fplace%2FC18175EA5858444A8FF6D04F75F3674B 5.0
# https://place.map.kakao.com/2017332074
# 남원스테이 //t1.kakaocdn.net/thumb/T800x0.q80/?fname=http%3A%2F%2Ft1.kakaocdn.net%2Ffiy_reboot%2Fplace%2F921E4F99D5D846609E546F871DD2F076 5.0
# https://place.map.kakao.com/22959213
# 한라산풍경  5.0
# https://place.map.kakao.com/254234023
# 위미소망호  0.0
# 5  of  [  3  ]
# https://place.map.kakao.com/170530991
# 낙원게스트하우스  0.0
# https://place.map.kakao.com/25476392
# 제주나무토방 //t1.kakaocdn.net/thumb/T800x0.q80/?fname=http%3A%2F%2Ft1.daumcdn.net%2Fcfile%2F250E4E4153D3018940 0.0
# https://place.map.kakao.com/425932814
# 예촌민박  0.0
# https://place.map.kakao.com/8113188
# 팔도민박  0.0
# https://place.map.kakao.com/13025921
# 제주펜션예촌  5.0
# https://place.map.kakao.com/1917987016
# 미라벨 제주 //t1.kakaocdn.net/thumb/T800x0.q80/?fname=http%3A%2F%2Ft1.kakaocdn.net%2Ffiy_reboot%2Fplace%2FB6F8C27A44C643CD8E113965797DEB1B 0.0
# https://place.map.kakao.com/1757111938
# 모드락펜션  0.0
# https://place.map.kakao.com/1725704602
# 서귀포행복펜션  0.0
# https://place.map.kakao.com/243580658
# 제주비 앨리스 //t1.kakaocdn.net/thumb/T800x0.q80/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flocalfiy%2FCAB77ACB3697415F969ED912FF057F79 0.0
# https://place.map.kakao.com/1851616184
# 남가원  0.0
# https://place.map.kakao.com/770825054
# 정원집 //t1.kakaocdn.net/thumb/T800x0.q80/?fname=http%3A%2F%2Ft1.kakaocdn.net%2Ffiy_reboot%2Fplace%2F552519543A314F35B71C11156F97D83A 0.0
# https://place.map.kakao.com/14557956
# 밀려오는파도소리  0.0
# https://place.map.kakao.com/651088014
# 이락펜션  0.0
# https://place.map.kakao.com/285593103
# 제이앤스테이 //t1.kakaocdn.net/thumb/T800x0.q80/?fname=http%3A%2F%2Ft1.kakaocdn.net%2Ffiy_reboot%2Fplace%2FC594E6C3AC0D40D3AB7BD3E90F713F23 0.0
# https://place.map.kakao.com/975063135
# 수망스테이  5.0
# 1  of  [  4  ]
# https://place.map.kakao.com/1132325626
# 달뜬제주 //t1.kakaocdn.net/thumb/T800x0.q80/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flocalfiy%2F44AC120403414C42AC7918D669DA4FAF 0.0
# https://place.map.kakao.com/268724785
# 마니팬션 한남리점  0.0
# https://place.map.kakao.com/24062253
# 휴민박  0.0
# https://place.map.kakao.com/1869748324
# 바띠에  0.0
# https://place.map.kakao.com/13727348
# 영등현동순할망집  0.0
# https://place.map.kakao.com/1464633384
# 루비스테이 //t1.kakaocdn.net/thumb/T800x0.q80/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flocalfiy%2F5FAF377EA7594E56B749DA67FFC17C8F 0.0
# https://place.map.kakao.com/1693634773
# 스테이어게인  0.0
# https://place.map.kakao.com/167203810
# 고니하우스  0.0
# https://place.map.kakao.com/946655705
# 돌담하우스  0.0
# https://place.map.kakao.com/461799499
# 뜰안에펜션  0.0
# https://place.map.kakao.com/1204084193
# 제주해마루 게스트하우스  0.0
# https://place.map.kakao.com/2042388722
# 귤밭정원  0.0
# https://place.map.kakao.com/1857181500
# 제주 산내들 여행사  0.0
# https://place.map.kakao.com/18049352
# 영빌리지  0.0
# https://place.map.kakao.com/1539273101
# 가을별빛네  0.0
# 2  of  [  4  ]
# https://place.map.kakao.com/13188045
# 큰엉민박  0.0
# https://place.map.kakao.com/1870749684
# 새사르  0.0
# https://place.map.kakao.com/9484701
# 큰엉가족마을  0.0
# https://place.map.kakao.com/2051226796
# 에비앙빌리지40펜션  0.0
# https://place.map.kakao.com/24943168
# 신흥민박  0.0
# https://place.map.kakao.com/9573339
# 한영민박  0.0
# https://place.map.kakao.com/25540315
# 봉진하우스  0.0
# https://place.map.kakao.com/23971824
# 한라산가는길펜션  0.0
# https://place.map.kakao.com/12355671
# 삼천리민박  0.0
# https://place.map.kakao.com/475784544
# 미니하우스  0.0
# https://place.map.kakao.com/1938847206
# 제주옆집 //t1.kakaocdn.net/thumb/T800x0.q80/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flocalfiy%2F40F3F1F1EC754315A3B6E3B3875D3C94 0.0
# https://place.map.kakao.com/428569835
# 스테이 831  0.0
# https://place.map.kakao.com/18754137
# 놀멍올레펜션  0.0
# https://place.map.kakao.com/27240445
# 달공게스트하우스  0.0
# https://place.map.kakao.com/223519293
# 제주외가 //t1.kakaocdn.net/thumb/T800x0.q80/?fname=http%3A%2F%2Ft1.kakaocdn.net%2Fmystore%2FE40C883FB26147EB8932B35583D309C3 0.0
# 3  of  [  4  ]
# https://place.map.kakao.com/27455241
# 아바마인드하우스  0.0
# https://place.map.kakao.com/1314139940
# 패밀리하우스 //t1.kakaocdn.net/thumb/T800x0.q80/?fname=http%3A%2F%2Ft1.kakaocdn.net%2Ffiy_reboot%2Fplace%2FC86D3D7D671546CC98059EB14F708E47 0.0
# https://place.map.kakao.com/23972702
# 가산빌민박  4.0
# https://place.map.kakao.com/1666991510
# 유정이네  0.0
# https://place.map.kakao.com/1194041053
# 사계절  0.0
# https://place.map.kakao.com/601684163
# 이웃집365  0.0
# https://place.map.kakao.com/885911045
# 윤서내 해피하우스  0.0
# https://place.map.kakao.com/819027492
# 노닐so  0.0
# https://place.map.kakao.com/1600836290
# 그랜맘  0.0
# https://place.map.kakao.com/1618920430
# 방구동 산책  0.0
# https://place.map.kakao.com/762163063
# 하품  0.0
# https://place.map.kakao.com/2073066800
# 더 재벌  5.0
# https://place.map.kakao.com/1454749780
# 바다 별  0.0
# https://place.map.kakao.com/26375674
# 강변민박  0.0
# https://place.map.kakao.com/8656377
# 소노캄 제주  3.4
# 4  of  [  4  ]
# https://place.map.kakao.com/1898134512
# 블랙랜드레이스 //t1.kakaocdn.net/thumb/T800x0.q80/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flocalfiy%2
//t1.kakaocdn.net/thumb/T800x0.q80/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flocalfiy%2F179B0A67FC9F4AF3A91710C4DF59CA10 0.0
# https://place.map.kakao.com/1962248391
# 제주유유자적펜션 //t1.kakaocdn.net/thumb/T800x0.q80/?fname=http%3A%2F%2Ft1.daumcdn.net%2Fcfile%2F223A463C57272B4D23 5.0
# https://place.map.kakao.com/1221952026
# 스트리트28펜션  0.0
# https://place.map.kakao.com/1817226267
# 십이계절게스트하우스  4.0
# https://place.map.kakao.com/26942564
# 모코네하우스  0.0
# https://place.map.kakao.com/26519967
# 씨엘빌리지 //t1.kakaocdn.net/thumb/T800x0.q80/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flocalfiy%2FA59D2C14D6574E4E96DA3FE9C7BC9C07 0.0
# https://place.map.kakao.com/18661257
# 행운클로버펜션 //t1.kakaocdn.net/thumb/T800x0.q80/?fname=http%3A%2F%2Ft1.daumcdn.net%2Fcfile%2F1565EB3D50DBD19E39 2.0
# https://place.map.kakao.com/892204705
# 스마트풀빌라  0.0
# https://place.map.kakao.com/23970831
# 덕산민박  0.0
# https://place.map.kakao.com/22456300
# 바로그펜션  0.0
# https://place.map.kakao.com/1840641450
# 봄봄스파앤풀빌라  5.0
# https://place.map.kakao.com/1705135580
# 푸른섬게스트하우스 //t1.kakaocdn.net/thumb/T800x0.q80/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flocalfiy%2F067884DB066C4F25B8ACE45E59101457 5.0
# 2  of  [  5  ]
# https://place.map.kakao.com/27167182
# 우리두리게스트하우스  0.0
# https://place.map.kakao.com/212408519
# 북극에서만나행복하자  0.0
# https://place.map.kakao.com/166547941
# 맘스베케이션 //t1.kakaocdn.net/thumb/T800x0.q80/?fname=http%3A%2F%2Ft1.kakaocdn.net%2Fmystore%2F983FDC06D30C496D98EE7E0829B94E01 0.0
# https://place.map.kakao.com/1121543776
# 제주소망펜션  5.0
# https://place.map.kakao.com/431176927
# 언니네옆집  0.0
# https://place.map.kakao.com/1058515032
# 마니펜션 세화점  0.0
# https://place.map.kakao.com/20471268
# 즐겨찾기 게스트하우스  0.0
# https://place.map.kakao.com/113528929
# 혜정하우스펜션  0.0
# https://place.map.kakao.com/25611498
# 슈에뜨펜션  0.0
# https://place.map.kakao.com/25540322
# 우리바다펜션  3.0
# https://place.map.kakao.com/730583301
# 헤세드하우스펜션  0.0
# https://place.map.kakao.com/27436511
# 로만토피아 //t1.kakaocdn.net/thumb/T800x0.q80/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flocalfiy%2FE64D84B7F4E74CC3990AD9001DF90CDE 5.0
# https://place.map.kakao.com/26458547
# 미로객잔  4.8
# https://place.map.kakao.com/341068739
# 카세로지 //t1.kakaocdn.net/thumb/T800x0.q80/?fname=http%3A%2F%2Ft1.kakaocdn.net%2Fmystore%2F4EA7A90C0BE948F4B2AEA63CE1CD63CB 5.0
# https://place.map.kakao.com/833800562
# 아연민박  0.0
# 3  of  [  5  ]
# https://place.map.kakao.com/26041152
# 쇠소깍 휴양펜션 엘마르 //t1.kakaocdn.net/thumb/T800x0.q80/?fname=http%3A%2F%2Ft1.daumcdn.net%2Fplace%2FF1D57631BBBB49C6B20F3FF9F7E65A8F 4.3
# https://place.map.kakao.com/1628278785
# 세화부엉이  0.0
# https://place.map.kakao.com/25622406
# 티롤펜션  0.0
# https://place.map.kakao.com/26425554
# 루하우스 //t1.kakaocdn.net/thumb/T800x0.q80/?fname=http%3A%2F%2Ft1.daumcdn.net%2Fcfile%2F2609BA4354AA7F5302 0.0
# https://place.map.kakao.com/1926682958
# 제주킹덤타운하우스 //t1.kakaocdn.net/thumb/T800x0.q80/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flocalfiy%2FA5D3AA87EB1D4581B457592203FD9311 0.0
# https://place.map.kakao.com/671905494
# 민들레하우스  0.0
# https://place.map.kakao.com/2115386591
# 르가든풀빌라  0.0
# https://place.map.kakao.com/730526807
# 브리드인제주 //t1.kakaocdn.net/thumb/T800x0.q80/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flocalfiy%2Fsearchregister_468044213 4.0
# https://place.map.kakao.com/1741014532
# 제주율하우스 //t1.kakaocdn.net/thumb/T800x0.q80/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flocalad_thumb%2Ft%2F2052b7d0f00a0878a250e84b25f74124736a2edc 5.0
# https://place.map.kakao.com/2069447998
# 561펜션  0.0
# https://place.map.kakao.com/8507319
# 제주스카이휴양펜션  1.0
# https://place.map.kakao.com/69649985
# 지니하우스 //t1.kakaocdn.net/thumb/T800x0.q80/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flocalfiy%2FD522903675F44A1D833E1B7A7CF42949 5.0
# https://place.map.kakao.com/675885717
# 와우펜션  0.0
# https://place.map.kakao.com/10103508
# 크라운캐슬펜션 //t1.kakaocdn.net/thumb/T800x0.q80/?fname=http%3A%2F%2Ft1.daumcdn.net%2Fcfile%2F16517A454F7A77C401 5.0
# https://place.map.kakao.com/435988290
# 빈도롱이가 //t1.kakaocdn.net/thumb/T800x0.q80/?fname=http%3A%2F%2Ft1.kakaocdn.net%2Ffiy_reboot%2Fplace%2FE2648FF1638C46158703303A512DD26D 5.0
# 4  of  [  5  ]
# https://place.map.kakao.com/27547714
# 돌집바이신대장  5.0
# https://place.map.kakao.com/161946299
# 소금막호스텔  4.2
# https://place.map.kakao.com/25017584
# 희망펜션 //t1.kakaocdn.net/thumb/T800x0.q80/?fname=http%3A%2F%2Ft1.daumcdn.net%2Fcfile%2F2650BD3F53D0B28126 5.0
# https://place.map.kakao.com/1480806410
# 아띠애펜션  5.0
# https://place.map.kakao.com/407506999
# 체리홈스테이  0.0
# https://place.map.kakao.com/1410944890
# 하귤당  5.0
# https://place.map.kakao.com/1244030390
# 제주하늘스테이 //t1.kakaocdn.net/thumb/T800x0.q80/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flocalfiy%2Fsearchregister_859543035 0.0
# https://place.map.kakao.com/809036108
# 쇠소깍섬도리왓펜션  5.0
# https://place.map.kakao.com/12535409
# 표선가시리민박  5.0
# https://place.map.kakao.com/1437488217
# 애드타임하우스 //t1.kakaocdn.net/thumb/T800x0.q80/?fname=http%3A%2F%2Ft1.daumcdn.net%2Fcfile%2F25701E39577F40ED32 0.0
# https://place.map.kakao.com/1115063856
# 가시버시  0.0
# https://place.map.kakao.com/1297137245
# 유채꽃길에머문시간펜션 //t1.kakaocdn.net/thumb/T800x0.q80/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flocalfiy%2Fsearchregister_1621945510 0.0
# https://place.map.kakao.com/963346152
# 샤인빌펜션  0.0
# https://place.map.kakao.com/205269573
# 가시머뭄  0.0
# https://place.map.kakao.com/1285102649
# 하효일  5.0
# 5  of  [  5  ]
# https://place.map.kakao.com/712810428
# 가시리애  0.0
# https://place.map.kakao.com/1845000557
# 오육일house민박  0.0
# https://place.map.kakao.com/520982579
# 킹덤스테이 //t1.kakaocdn.net/thumb/T800x0.q80/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flocalfiy%2F1473BE3D3F3644869FA2E3457FC9462D 0.0
# https://place.map.kakao.com/361072714
# 프리폴링  0.0
# https://place.map.kakao.com/131903524
# 보금자리민박  0.0
# https://place.map.kakao.com/1384082892
# 시골친구펜션  0.0
# https://place.map.kakao.com/13727381
# 타시텔레 힐링농원 //t1.kakaocdn.net/thumb/T800x0.q80/?fname=http%3A%2F%2Ft1.daumcdn.net%2Fcfile%2F14543E344E23864F05 5.0
# https://place.map.kakao.com/26223819
# 금강민박  0.0
# https://place.map.kakao.com/13727466
# 효돈올레민박  0.0
# https://place.map.kakao.com/399132545
# 새벽별펜션 //t1.kakaocdn.net/thumb/T800x0.q80/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flocalfiy%2FB97607235DF142A0A6BCFE35B8703DDA 5.0
# https://place.map.kakao.com/184946747
# 꿈꾸는아이  0.0
# https://place.map.kakao.com/2122659881
# 놀멍놀멍가시리  0.0
# https://place.map.kakao.com/936346046
# 제주다움빌하우스  0.0
# https://place.map.kakao.com/113590255
# 솔  0.0
# https://place.map.kakao.com/994914336
# 윗시  0.0
# 1  of  [  6  ]
# https://place.map.kakao.com/2115060954
# 파도소리펜션  0.0
# https://place.map.kakao.com/2036421118
# 동훈네 집 //t1.kakaocdn.net/thumb/T800x0.q80/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flocalfiy%2FF4518C18547B44849960137F02DF91E9 0.0
# https://place.map.kakao.com/1873330236
# Hee스토리제주  0.0
# https://place.map.kakao.com/2104145132
# 개운하우스  0.0
# https://place.map.kakao.com/1645289335
# 하효민박  0.0
# https://place.map.kakao.com/1866639676
# 표선휴펜션  5.0
# 2  of  [  6  ]
# End of Page
# Arrow is Disabled
# End of Crawl
