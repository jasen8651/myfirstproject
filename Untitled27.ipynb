# %% [markdown]
# <a href="https://colab.research.google.com/github/jasen8651/python001/blob/master/Untitled27.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## 구글 드라이브 연결
from google.colab import drive
drive.mount('/content/drive')

#  경로 변경
# %cd /content/drive/MyDrive/python_demo
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/python_demo

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/drive/MyDrive/python_demo/pdsample/숙소정보크롤링.csv', sep=',', encoding='cp949')
df
# Out:
#       Unnamed: 0        숙소id                          숙박이름  객실타입       타입  \
# 0              0       24208                       제주 T무인텔     1    Motel
# 1              1       24993              제주 한림 이쁜새이쁘게노래하고     1    Motel
# 2              2       26406                         제주 JM     1    Motel
# 3              3       26412  제주 Fantastic Oceanview 시드니호텔     1    Motel
# 4              4       26442                         제주 하루     1    Motel
# ...          ...         ...                           ...   ...      ...
# 1536        1536  1000123163                    제주 달콤한아침펜션     3  Pension
# 1537        1537  1000123573                    제주 다님독채풀빌라     3  Pension
# 1538        1538  1000123574                제주 알프스인소길스테이펜션     3  Pension
# 1539        1539  1000123575                    서귀포 제주애풀빌라     3  Pension
# 1540        1540  1000123595                    제주 애월애휴양펜션     3  Pension
#
#         체크인   체크아웃            번호                          주소   대분류   중분류  \
# ...

# %%
year_df=pd.read_csv('/content/drive/MyDrive/python_demo/pdsample/리뷰태그.csv', sep=',', encoding='cp949')
year_df
# Out:
#              숙소id  태그2
# 0           24208  깨끗함
# 1           24208  NaN
# 2           24208  NaN
# 3           24208  친절함
# 4           24208  NaN
# ...           ...  ...
# 27598  1000122715  깨끗함
# 27599  1000122715  NaN
# 27600  1000122715  깨끗함
# 27601  1000122715   외관
# 27602  1000123163  깨끗함
#
# [27603 rows x 2 columns]

# %%
df['숙소id'] = year_df['숙소id'].apply(str)

# %%
data=pd.merge(df, year_df, on=['숙소id'], how='inner')
data
# Out:
#        Unnamed: 0        숙소id        숙박이름  객실타입       타입    체크인   체크아웃  \
# 0               0       24208     제주 T무인텔     1    Motel  18:00  12:00
# 1               0       24208     제주 T무인텔     1    Motel  18:00  12:00
# 2               0       24208     제주 T무인텔     1    Motel  18:00  12:00
# 3               0       24208     제주 T무인텔     1    Motel  18:00  12:00
# 4               0       24208     제주 T무인텔     1    Motel  18:00  12:00
# ...           ...         ...         ...   ...      ...    ...    ...
# 27437        1533  1000122715     제주 델마펜션     3  Pension  16:00  11:00
# 27438        1533  1000122715     제주 델마펜션     3  Pension  16:00  11:00
# 27439        1533  1000122715     제주 델마펜션     3  Pension  16:00  11:00
# 27440        1533  1000122715     제주 델마펜션     3  Pension  16:00  11:00
# 27441        1536  1000123163  제주 달콤한아침펜션     3  Pension  17:00  10:00
#
#                  번호                        주소  대분류   중분류           소분류  \
# ...

# %%
data2 = pd.DataFrame(data)
data2.to_csv('숙소태그추가.csv',index=False,mode="a")

# %%
data2
# Out:
#        Unnamed: 0        숙소id        숙박이름  객실타입       타입    체크인   체크아웃  \
# 0               0       24208     제주 T무인텔     1    Motel  18:00  12:00
# 1               0       24208     제주 T무인텔     1    Motel  18:00  12:00
# 2               0       24208     제주 T무인텔     1    Motel  18:00  12:00
# 3               0       24208     제주 T무인텔     1    Motel  18:00  12:00
# 4               0       24208     제주 T무인텔     1    Motel  18:00  12:00
# ...           ...         ...         ...   ...      ...    ...    ...
# 27437        1533  1000122715     제주 델마펜션     3  Pension  16:00  11:00
# 27438        1533  1000122715     제주 델마펜션     3  Pension  16:00  11:00
# 27439        1533  1000122715     제주 델마펜션     3  Pension  16:00  11:00
# 27440        1533  1000122715     제주 델마펜션     3  Pension  16:00  11:00
# 27441        1536  1000123163  제주 달콤한아침펜션     3  Pension  17:00  10:00
#
#                  번호                        주소  대분류   중분류           소분류  \
# ...
