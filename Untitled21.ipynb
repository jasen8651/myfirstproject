# %% [markdown]
# <a href="https://colab.research.google.com/github/jasen8651/python001/blob/master/Untitled21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/python_demo
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/python_demo

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/drive/MyDrive/python_demo/제주도숙소 정보.csv', sep=',', encoding='cp949')
df
# Out:
#               id                          숙박이름  객실타입       타입    체크인   체크아웃  \
# 0          24208                       제주 T무인텔     1    Motel  18:00  12:00
# 1          24993              제주 한림 이쁜새이쁘게노래하고     1    Motel  15:00  11:00
# 2          26406                         제주 JM     1    Motel  14:00  12:00
# 3          26412  제주 Fantastic Oceanview 시드니호텔     1    Motel  15:00  11:00
# 4          26442                         제주 하루     1    Motel  15:00  12:00
# ...          ...                           ...   ...      ...    ...    ...
# 1562  1000123163                    제주 달콤한아침펜션     3  Pension  17:00  10:00
# 1563  1000123573                    제주 다님독채풀빌라     3  Pension  16:00  11:00
# 1564  1000123574                제주 알프스인소길스테이펜션     3  Pension  16:00  11:00
# 1565  1000123575                    서귀포 제주애풀빌라     3  Pension  16:00  11:00
# 1566  1000123595                    제주 애월애휴양펜션     3  Pension  15:00  11:00
#
# ...

# %%
year_df=pd.read_csv('/content/drive/MyDrive/python_demo/어메니티.csv', sep=',', encoding='cp949')
year_df
# Out:
#                id   FXTR_CD   FXTR_NM
# 0       1000123737      104      와이파이
# 1       1000123737   100146    해수욕장인근
# 2       1000123737   100135     개별바베큐
# 3       1000123737   100012      주차가능
# 4       1000123621      106  스파/월풀/욕조
# ...            ...      ...       ...
# 149795       23184   100105      어메니티
# 149796       23184   100103     수화물보관
# 149797       23184   100102   24시간데스크
# 149798       23184   100101     객실내PC
# 149799       23184   100012      주차가능
#
# [149800 rows x 3 columns]

# %%
# data=pd.merge(df,year_df,left_on=['숙박id'],right_on=['숙박id'],how='inner')
# data

# %%
year_df.iloc[3]
# Out:
# id         1000123737
# FXTR_CD        100012
# FXTR_NM          주차가능
# Name: 3, dtype: object

# %%
df.iloc[0]
/content/drive/MyDrive/python_demo/어메니티.csv
# Out:
# id                                24208
# 숙박이름                            제주 T무인텔
# 객실타입                                  1
# 타입                                Motel
# 체크인                               18:00
# 체크아웃                              12:00
# 번호                        50350500309.0
# 주소             제주특별자치도 제주시 조천읍 남조로 2393
# 대분류                                 제주시
# 중분류                                 조천읍
# 소분류                        한림읍 협재로 68-5
# X                             126.24696
# Y                             33.392206
# 대표사진                                NaN
# 숙소소개                                NaN
# 평점                                  NaN
# 태그(인기및 서비스)                         NaN
# 태그 이미지                              NaN
# Name: 0, dtype: object

# %%
year_df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 149795    False
# 149796    False
# 149797    False
# 149798    False
# 149799    False
# Length: 149800, dtype: bool

# %%
year_df.drop_duplicates()
# Out:
#                id   FXTR_CD   FXTR_NM
# 0       1000123737      104      와이파이
# 1       1000123737   100146    해수욕장인근
# 2       1000123737   100135     개별바베큐
# 3       1000123737   100012      주차가능
# 4       1000123621      106  스파/월풀/욕조
# ...            ...      ...       ...
# 149795       23184   100105      어메니티
# 149796       23184   100103     수화물보관
# 149797       23184   100102   24시간데스크
# 149798       23184   100101     객실내PC
# 149799       23184   100012      주차가능
#
# [149800 rows x 3 columns]

# %%
year_df
# Out:
#                id   FXTR_CD   FXTR_NM
# 0       1000123737      104      와이파이
# 1       1000123737   100146    해수욕장인근
# 2       1000123737   100135     개별바베큐
# 3       1000123737   100012      주차가능
# 4       1000123621      106  스파/월풀/욕조
# ...            ...      ...       ...
# 149795       23184   100105      어메니티
# 149796       23184   100103     수화물보관
# 149797       23184   100102   24시간데스크
# 149798       23184   100101     객실내PC
# 149799       23184   100012      주차가능
#
# [149800 rows x 3 columns]

# %%
Pass = np.concatenate(file['키워드'].values.tolist())
print(Pass)

genre_list = np.concatenate(year_df['FXTR_NM']).tolist()
print(genre_list) # list

genres_list = set(genre_list)
print(genres_list) # set 중복값 x
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-61338642db3f> in <module>
# ----> 1 genre_list = np.concatenate(year_df['FXTR_NM']).values.shape
#       2 print(genre_list) # list
#       3
#       4 genres_list = set(genre_list)
#       5 print(genres_list) # set 중복값 x
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: zero-dimensional arrays cannot be concatenated

# %%
pd.merge(df, year_df, left_on='id',right_on='id')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-8c529cec7275> in <module>
# ----> 1 pd.merge(df, year_df, left_on='id',right_on='id')
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     104     validate: str | None = None,
#     105 ) -> DataFrame:
# --> 106     op = _MergeOperation(
#     107         left,
#     108         right,
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     697             self.right_join_keys,
#     698             self.join_names,
# --> 699         ) = self._get_merge_keys()
#     700
# ...

# %%
data2= pd.merge(df, year_df, on='id', how='outer')
data2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-4fdcfab358b8> in <module>
# ----> 1 data2= pd.merge(df, year_df, on='id', how='outer')
#       2 data2
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     104     validate: str | None = None,
#     105 ) -> DataFrame:
# --> 106     op = _MergeOperation(
#     107         left,
#     108         right,
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     697             self.right_join_keys,
#     698             self.join_names,
# --> 699         ) = self._get_merge_keys()
#     700
# ...

# %%
data2 = pd.DataFrame(data)
data2.to_csv('테스트.csv',index=False,mode="a")
