# %% [markdown]
# <a href="https://colab.research.google.com/github/jasen8651/python001/blob/master/Untitled26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## 구글 드라이브 연결
from google.colab import drive
drive.mount('/content/drive')

#  경로 변경
# %cd /content/drive/MyDrive/python_demo
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/python_demo

# %%
import numpy as np
import pandas as pd

# df=pd.read_csv('/content/drive/MyDrive/python_demo/pdsample/숙소정보크롤링.csv', sep=',', encoding='cp949')
# df

# %%
df=pd.read_csv('/content/drive/MyDrive/python_demo/pdsample/객실정보크롤링.csv', sep=',', encoding='cp949')
df
# Out:
#       Unnamed: 0        숙소id           객실이름         가격
# 0              0       24208            일반실   50,000원~
# 1              1       24993         15평 원룸   49,000원~
# 2              2       26406  Standard Twin   45,000원~
# 3              3       26406    Deluxe Twin   60,000원~
# 4              4       26406         On-dol   75,000원~
# ...          ...         ...            ...        ...
# 8052        1605  1000123595   106동 22평형 독채  109,980원~
# 8053        1606  1000123595   105동 33평형 독채  160,740원~
# 8054        1607  1000123595   103동 33평형 독채  160,740원~
# 8055        1608  1000123595   102동 33평형 독채  160,740원~
# 8056        1609  1000123595   101동 33평형 독채  160,740원~
#
# [8057 rows x 4 columns]

# %%
df.dtypes
# Out:
# Unnamed: 0     int64
# 숙소id           int64
# 객실이름          object
# 가격            object
# dtype: object

# %%
year_df.dtypes
# Out:
# 숙소id      int64
# 숙소이름     object
# 객실id      int64
# 객실이름     object
# 기본공지     object
# 최소인원    float64
# 최대인원    float64
# dtype: object

# %%
year_df=pd.read_csv('/content/drive/MyDrive/python_demo/pdsample/객실테이블.csv', sep=',', encoding='cp949')
# year_df = year_df.astype({'객실id' : 'object'})
# year_df = year_df.astype({'숙소id' : 'object'})

# %%
year_df
# Out:
#              숙소id              숙소이름    객실id                     객실이름  \
# 0           24208           제주 T무인텔    4376                      일반실
# 1           24993  제주 한림 이쁜새이쁘게노래하고   24078                   15평 원룸
# 2           26406             제주 JM  429776  Standard Twin(28 Rooms)
# 3           26406             제주 JM  429777     Deluxe Twin(6 Rooms)
# 4           26406             제주 JM  429778          On-dol(2 Rooms)
# ...           ...               ...     ...                      ...
# 10001  1000123595        제주 애월애휴양펜션  512315             108동 22평형 독채
# 10002  1000123595        제주 애월애휴양펜션  512316             109동 22평형 독채
# 10003  1000123595        제주 애월애휴양펜션  512317             111동 22평형 독채
# 10004  1000123595        제주 애월애휴양펜션  512318             107동 10평형 독채
# 10005  1000123595        제주 애월애휴양펜션  512319             110동 10평형 독채
#
#                                                     기본공지  최소인원  최대인원
# 0                                                    NaN   2.0   2.0
# 1                                                    NaN   2.0   2.0
# 2                                                    NaN   2.0   2.0
# 3                                                    NaN   2.0   2.0
# 4                                                    NaN   2.0   2.0
# ...                                                  ...   ...   ...
# 10001  인원 추가 정보, - 인원 : 기준 3명 / 최대 5명, - 인원추가 : 불가능, ...   NaN   NaN
# 10002  인원 추가 정보, - 인원 : 기준 3명 / 최대 5명, - 인원추가 : 불가능, ...   NaN   NaN
# 10003  인원 추가 정보, - 인원 : 기준 3명 / 최대 5명, - 인원추가 : 불가능, ...   NaN   NaN
# 10004  인원 추가 정보, - 인원 : 기준 2명 / 최대 3명, - 인원추가 : 불가능, ...   NaN   NaN
# 10005  인원 추가 정보, - 인원 : 기준 2명 / 최대 3명, - 인원추가 : 불가능, ...   NaN   NaN
#
# [10006 rows x 7 columns]

# %%
df['숙소id'] = year_df['숙소id'].apply(str)

# %%
data=pd.merge(df, year_df, on=['숙소id','객실이름'], how='inner')
data
# Out:
#       Unnamed: 0        숙소id               객실이름         가격  \
# 0              0       24208                일반실   50,000원~
# 1              1       24993             15평 원룸   49,000원~
# 2              5       26412  Sky&Ocean Village  120,000원~
# 3              6       26412        신관 오션뷰 스위트룸   63,000원~
# 4              7       26412         본관 스탠다드 더블   40,000원~
# ...          ...         ...                ...        ...
# 6257        1605  1000123595       106동 22평형 독채  109,980원~
# 6258        1606  1000123595       105동 33평형 독채  160,740원~
# 6259        1607  1000123595       103동 33평형 독채  160,740원~
# 6260        1608  1000123595       102동 33평형 독채  160,740원~
# 6261        1609  1000123595       101동 33평형 독채  160,740원~
#
#                               숙소이름    객실id  \
# 0                          제주 T무인텔    4376
# 1                 제주 한림 이쁜새이쁘게노래하고   24078
# 2     제주 Fantastic Oceanview 시드니호텔  344688
# 3     제주 Fantastic Oceanview 시드니호텔  323545
# 4     제주 Fantastic Oceanview 시드니호텔   51023
# ...                            ...     ...
# 6257                    제주 애월애휴양펜션  512314
# 6258                    제주 애월애휴양펜션  512312
# 6259                    제주 애월애휴양펜션  512309
# 6260                    제주 애월애휴양펜션  512307
# 6261                    제주 애월애휴양펜션  512304
#
#                                                    기본공지  최소인원  최대인원
# 0                                                   NaN   2.0   2.0
# 1                                                   NaN   2.0   2.0
# 2     추가인원 1인 당 1만5천원 추가되오니, 자세한 사항은 프런트로 문의부탁드립니다. ...   2.0   4.0
# 3                                                   NaN   2.0   2.0
# 4                                                   NaN   2.0   4.0
# ...                                                 ...   ...   ...
# 6257  인원 추가 정보, - 인원 : 기준 3명 / 최대 5명, - 인원추가 : 불가능, ...   NaN   NaN
# 6258  인원 추가 정보, - 인원 : 기준 5명 / 최대 8명, - 인원추가 : 불가능, ...   NaN   NaN
# 6259  인원 추가 정보, - 인원 : 기준 5명 / 최대 8명, - 인원추가 : 불가능, ...   NaN   NaN
# 6260  인원 추가 정보, - 인원 : 기준 5명 / 최대 8명, - 인원추가 : 불가능, ...   NaN   NaN
# 6261  인원 추가 정보, - 인원 : 기준 5명 / 최대 8명, - 인원추가 : 불가능, ...   NaN   NaN
#
# [6262 rows x 9 columns]

# %%
data2 = pd.DataFrame(data)
data2.to_csv('객실테이블가격포함3.csv',index=False,mode="a")
