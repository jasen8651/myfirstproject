# %% [markdown]
# <a href="https://colab.research.google.com/github/jasen8651/python001/blob/master/Untitled26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## 구글 드라이브 연결
from google.colab import drive
drive.mount('/content/drive')

#  경로 변경
# %cd /content/drive/MyDrive/python_demo
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/python_demo

# %%
import numpy as np
import pandas as pd

# df=pd.read_csv('/content/drive/MyDrive/python_demo/pdsample/숙소정보크롤링.csv', sep=',', encoding='cp949')
# df

# %%
df=pd.read_csv('/content/drive/MyDrive/python_demo/pdsample/숙소정보크롤링0228(AC)수정.csv', sep=',', encoding='cp949')
df
# Out:
#            AC_ID                       AC_NAME  AC_TYPE_NUMBER AC_TYPE_NAME  \
# 0          24208                       제주 T무인텔               1        Motel
# 1          24993              제주 한림 이쁜새이쁘게노래하고               1        Motel
# 2          26406                         제주 JM               1        Motel
# 3          26412  제주 Fantastic Oceanview 시드니호텔               1        Motel
# 4          26442                         제주 하루               1        Motel
# ...          ...                           ...             ...          ...
# 1536  1000123163                    제주 달콤한아침펜션               3      Pension
# 1537  1000123573                    제주 다님독채풀빌라               3      Pension
# 1538  1000123574                제주 알프스인소길스테이펜션               3      Pension
# 1539  1000123575                    서귀포 제주애풀빌라               3      Pension
# 1540  1000123595                    제주 애월애휴양펜션               3      Pension
#
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0     int64
# 숙소id           int64
# 객실이름          object
# 가격            object
# dtype: object

# %%
year_df.dtypes
# Out:
# 숙소id      int64
# 숙소이름     object
# 객실id      int64
# 객실이름     object
# 기본공지     object
# 최소인원    float64
# 최대인원    float64
# dtype: object

# %%
year_df=pd.read_csv('/content/drive/MyDrive/python_demo/pdsample/객실테이블0303(GR).csv', sep=',', encoding='cp949')
# year_df = year_df.astype({'객실id' : 'object'})
# year_df = year_df.astype({'숙소id' : 'object'})

# %%
year_df
# Out:
#       GR_ID    AC_ID  GR_NUMBER  GR_PERSON_MAX  GR_PERSON_MIN   GR_PRICE  \
# 0         0  24208.0       4376            2.0            2.0   50,000원~
# 1         1  24993.0      24078            2.0            2.0   49,000원~
# 2         2  26412.0     344688            4.0            2.0  120,000원~
# 3         3  26442.0     323545            2.0            2.0   63,000원~
# 4         4  26946.0      51023            4.0            2.0   40,000원~
# ...     ...      ...        ...            ...            ...        ...
# 6257   6257      NaN     512314            NaN            NaN  109,980원~
# 6258   6258      NaN     512312            NaN            NaN  160,740원~
# 6259   6259      NaN     512309            NaN            NaN  160,740원~
# 6260   6260      NaN     512307            NaN            NaN  160,740원~
# 6261   6261      NaN     512304            NaN            NaN  160,740원~
#
#                 GR_NAME                                          GR_INFORM
# ...

# %%
df['숙소id'] = year_df['AC_ID'].apply(str)

# %%
data=pd.merge(df,year_df,left_on=['AC_ID'],right_on=['AC_ID'],how='inner')
data
# Out:
#           AC_ID                       AC_NAME  AC_TYPE_NUMBER AC_TYPE_NAME  \
# 0         24208                       제주 T무인텔               1        Motel
# 1         24993              제주 한림 이쁜새이쁘게노래하고               1        Motel
# 2         26412  제주 Fantastic Oceanview 시드니호텔               1        Motel
# 3         26442                         제주 하루               1        Motel
# 4         26946                       제주 해피데이               1        Motel
# ..          ...                           ...             ...          ...
# 978  1000123163                    제주 달콤한아침펜션               3      Pension
# 979  1000123573                    제주 다님독채풀빌라               3      Pension
# 980  1000123574                제주 알프스인소길스테이펜션               3      Pension
# 981  1000123575                    서귀포 제주애풀빌라               3      Pension
# 982  1000123595                    제주 애월애휴양펜션               3      Pension
#
# ...

# %%
data2 = pd.DataFrame(data)
data2.to_csv('숙소테이블수정.csv',index=False,mode="a")

# %%
data2
# Out:
#         GR_ID     AC_ID  GR_PERSON_MAX  GR_PERSON_MIN   GR_PRICE GR_NAME  \
# 0        4376     24208            2.0            2.0   50,000원~     일반실
# 1        4376     24208            2.0            2.0   50,000원~     일반실
# 2        4376     24208            2.0            2.0   50,000원~     일반실
# 3       24078     24993            2.0            2.0   49,000원~  15평 원룸
# 4       24078     24993            2.0            2.0   49,000원~  15평 원룸
# ...       ...       ...            ...            ...        ...     ...
# 10698  510381  10048075            3.0            2.0  250,000원~   H1풀빌라
# 10699  510381  10048075            3.0            2.0  250,000원~   H1풀빌라
# 10700  510382  10048075            6.0            4.0  250,000원~   H2풀빌라
# 10701  510382  10048075            6.0            4.0  250,000원~   H2풀빌라
# 10702  510382  10048075            6.0            4.0  250,000원~   H2풀빌라
#
#                                                GR_INFORM      숙박id    객실id  \
# ...

# %%
#데이터 읽기 
df = pd.read_csv("/content/drive/MyDrive/python_demo/리뷰정보크롤링긍정부정.csv", encoding='cp949')
df

#데이터 수정
