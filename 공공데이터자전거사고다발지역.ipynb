# %% [markdown]
# <a href="https://colab.research.google.com/github/jasen8651/python001/blob/master/%EA%B3%B5%EA%B3%B5%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%9E%90%EC%A0%84%EA%B1%B0%EC%82%AC%EA%B3%A0%EB%8B%A4%EB%B0%9C%EC%A7%80%EC%97%AD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#공공데이터 포털 https://www.data.go.kr/data/15050998/fileData.do

import requests
import json
import sys

from google.colab import drive
drive.mount('/content/dirve')
# %cd /content/dirve/MyDrive/python_demo
# Out:
# Drive already mounted at /content/dirve; to attempt to forcibly remount, call drive.mount("/content/dirve", force_remount=True).
# /content/dirve/MyDrive/python_demo

# %%
url = 'http://apis.data.go.kr/B552061/frequentzoneBicycle/getRestFrequentzoneBicycle'
#url ='ody0NMom4lkbktSlfx1qhPpwW/ujTweJDhIjdKzPgZ8bInrzWDUU5ZRYk9DsJ38FV37L/coHEqyrLa31slAYfA=='
key = 'ody0NMom4lkbktSlfx1qhPpwW%2FujTweJDhIjdKzPgZ8bInrzWDUU5ZRYk9DsJ38FV37L%2FcoHEqyrLa31slAYfA%3D%3D'

params ={'serviceKey' : key, 'searchYearCd' : '2020', '' : '11', 'guGun' : '', 'type' : 'json', 'numOfRows' : '10', 'pageNo' : '1' }

response = requests.get(url, params=params)
print(dir(response))
print(type(response.content))
print(response.text)
print(type(response.content))
response.json()
# Out:
# ['__attrs__', '__bool__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__nonzero__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_content', '_content_consumed', '_next', 'apparent_encoding', 'close', 'connection', 'content', 'cookies', 'elapsed', 'encoding', 'headers', 'history', 'is_permanent_redirect', 'is_redirect', 'iter_content', 'iter_lines', 'json', 'links', 'next', 'ok', 'raise_for_status', 'raw', 'reason', 'request', 'status_code', 'text', 'url']
# <class 'bytes'>
# ...

# %%
#분석
#item 접근 
w_data = response.json()['items']['item']

# %%
#print(w_data)
for i in range(len(w_data)):
  print('spot_nm:'+w_data[i]['spot_nm'])
  print('경도'+ w_data[i]['lo_crd'])
  print('위도'+ w_data[i]['la_crd'])
# Out:
# spot_nm:서울특별시 종로구 청운동(자하문사거리 부근)
# 경도126.966081541031
# 위도37.592485810473
# spot_nm:서울특별시 종로구 종로3가(종로3가 부근)
# 경도126.992126317577
# 위도37.570245721963

# %%
responseDate = response.text
#print(responseDate)
#if response.status_code ==200:
dictdata = json.loads(responseDate)
type(dictdata)
# Out:
# dict

# %%
if response.status_code ==200:
  responseDate = response.text
  dictdata = json.loads(responseDate)
  print(type(dictdata))
  print(dictdata)

  #xd = xmltodict.parse(responseDate) xml 형식 dict로 변환
  #xdj =  json.dumps(xd, ensure_ascii=False) dict형식을 json형식 변환
  #xdjd = json.loads(xdj) json -> dict
  #djd = json.loads(responseDat) str -> dict
